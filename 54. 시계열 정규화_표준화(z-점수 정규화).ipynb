# %% [markdown]
# ## 표준화
# 데이터의 평균을 0으로, 표준편차를 1로 만들어 데이터를 표준 정규 분포에 맞도록 변환하는 방법
# - X_new = (X - mean)/std

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
# 시계열 데이터
dates = pd.date_range(start='2023-01-01', periods = 100, freq='D')
values = [10, 12, 11, 15, 9, 13, 8, 14, 10, 16] * 10

# 데이터 프레임
data = pd.DataFrame({'Date' : dates, 'Value' : values})
print(data)

# 표준화값 추출
x = data['Value'].values.reshape(-1, 1)
print(x)

# 표준화 적용
scaler = StandardScaler()
x_scaler = scaler.fit_transform(x)

# 표준화 된 값을 새로운 열에 추가
data['Value_scaler'] = x_scaler
print(data['Value_scaler'])

# 표준화된 값 출력
print(data['Value_scaler'])
# Out:
#          Date  Value
# 0  2023-01-01     10
# 1  2023-01-02     12
# 2  2023-01-03     11
# 3  2023-01-04     15
# 4  2023-01-05      9
# ..        ...    ...
# 95 2023-04-06     13
# 96 2023-04-07      8
# 97 2023-04-08     14
# 98 2023-04-09     10
# 99 2023-04-10     16
#
# [100 rows x 2 columns]
# [[10]
#  [12]
#  [11]
#  [15]
#  [ 9]
#  [13]
#  [ 8]
#  [14]
#  [10]
#  [16]
#  [10]
#  [12]
#  [11]
#  [15]
#  [ 9]
#  [13]
#  [ 8]
#  [14]
#  [10]
#  [16]
#  [10]
#  [12]
#  [11]
#  [15]
#  [ 9]
#  [13]
#  [ 8]
#  [14]
#  [10]
#  [16]
#  [10]
#  [12]
#  [11]
#  [15]
#  [ 9]
#  [13]
#  [ 8]
#  [14]
#  [10]
#  [16]
#  [10]
#  [12]
#  [11]
#  [15]
#  [ 9]
#  [13]
#  [ 8]
#  [14]
#  [10]
#  [16]
#  [10]
#  [12]
#  [11]
#  [15]
#  [ 9]
#  [13]
#  [ 8]
#  [14]
#  [10]
#  [16]
#  [10]
#  [12]
#  [11]
#  [15]
#  [ 9]
#  [13]
#  [ 8]
#  [14]
#  [10]
#  [16]
#  [10]
#  [12]
#  [11]
#  [15]
#  [ 9]
#  [13]
#  [ 8]
#  [14]
#  [10]
#  [16]
#  [10]
#  [12]
#  [11]
#  [15]
#  [ 9]
#  [13]
#  [ 8]
#  [14]
#  [10]
#  [16]
#  [10]
#  [12]
#  [11]
#  [15]
#  [ 9]
#  [13]
#  [ 8]
#  [14]
#  [10]
#  [16]]
# 0    -0.713746
# 1     0.079305
# 2    -0.317221
# 3     1.268883
# 4    -1.110272
#         ...
# 95    0.475831
# 96   -1.506798
# 97    0.872357
# 98   -0.713746
# 99    1.665408
# Name: Value_scaler, Length: 100, dtype: float64
# 0    -0.713746
# 1     0.079305
# 2    -0.317221
# 3     1.268883
# 4    -1.110272
#         ...
# 95    0.475831
# 96   -1.506798
# 97    0.872357
# 98   -0.713746
# 99    1.665408
# Name: Value_scaler, Length: 100, dtype: float64
